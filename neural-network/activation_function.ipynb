# %%
import numpy as np
import matplotlib.pyplot as plt
import sys, os
sys.path.append(os.pardir)

from common.functions import step_function, sigmoid, relu

# %% [markdown]
# ## plot

# %%
x = np.arange(-5.0, 5.0, 0.1)
y_step = step_function(x)
y_sig = sigmoid(x)
y_relu = relu(x)

plt.plot(x, y_step)
plt.plot(x, y_sig)
plt.ylim(-0.1, 1.1)
plt.show()

plt.plot(x, y_relu)
plt.ylim(-1, 5.5)
plt.show()
